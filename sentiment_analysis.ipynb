# %% [markdown]
# # 商品評論-情感分析 sentiment analysis

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\elsie\pycharmprojects\sentiment_test\venv\lib\site-packages (1.2.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\elsie\pycharmprojects\sentiment_test\venv\lib\site-packages (from pandas) (2020.5)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\elsie\pycharmprojects\sentiment_test\venv\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\elsie\pycharmprojects\sentiment_test\venv\lib\site-packages (from pandas) (2.8.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six>=1.5 in c:\users\elsie\pycharmprojects\sentiment_test\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd
from textblob import TextBlob
import os
import statistics

# %%
df = pd.read_csv('./amzon_ETL_20201218.csv') #讀取商品清單20個
itemlist = df['Description'].tolist() #將商品放進list中，方便將空白取代'_'
itemlist
# Out:
# ['FLUID MILK WHITE ONLY',
#  'YOGURT NOT MULTI PACKS',
#  'SOFT DRINKS CAN',
#  'SOFT DRINK INCL',
#  'CANDY BARS',
#  'SHREDDED CHEESE',
#  'MAINSTREAM WHITE BREAD',
#  'CONDENSED SOUP',
#  'ECONOMY ENTREES DINNERS',
#  'BANANAS',
#  'SOFT DRINK POWDER POUCHES',
#  'POTATO CHIPS',
#  'PASTA CANNED',
#  'ICE CREAM',
#  'RAMEN NOODLES RAMEN CUPS',
#  'BEER',
#  '100% PURE JUICE',
#  'PREMIUM ENTREES',
#  'VEGETABLES PLAIN',
#  'TUNA']

# %%
itemlistt=[] #空list，將更新後的20個商品放入
for x in itemlist:
    x = x.replace(' ','_')
#     print(x) #type=str
    itemlistt.append(x)
itemlistt
# Out:
# ['FLUID_MILK_WHITE_ONLY',
#  'YOGURT_NOT_MULTI_PACKS',
#  'SOFT_DRINKS_CAN',
#  'SOFT_DRINK_INCL',
#  'CANDY_BARS',
#  'SHREDDED_CHEESE',
#  'MAINSTREAM_WHITE_BREAD',
#  'CONDENSED_SOUP',
#  'ECONOMY_ENTREES_DINNERS',
#  'BANANAS',
#  'SOFT_DRINK_POWDER_POUCHES',
#  'POTATO_CHIPS',
#  'PASTA_CANNED',
#  'ICE_CREAM',
#  'RAMEN_NOODLES_RAMEN_CUPS',
#  'BEER',
#  '100%_PURE_JUICE',
#  'PREMIUM_ENTREES',
#  'VEGETABLES_PLAIN',
#  'TUNA']

# %%
web = ['amazon_reviews','target_reviews','wegmans_reviews']
for j in web:
    total_score=[]
    items=[]
    for i in itemlistt:  #商品清單
        path="./"+j+'/'+i+'.txt'  #每個商品評論之檔名
#         print(path)
        try:
            with open(path,'r',encoding='utf-8') as f:
                reviews=f.readlines()  #讀取每條評論 
                
            new_reviews=[]
            for rev in reviews:
                rev=rev.replace('-','').replace('\n','').strip()
                if rev != '':
                    new_reviews.append(rev)
                else:
                    pass

            # print(new_reviews)
            score=[]
            for word in new_reviews:
#                 print(word) #type='str'
                blob = TextBlob(word)
#                 print(blob.sentences)

            #         a = blob.sentences[0].sentiment  #第一句的分析
                a = blob.sentiment
                score.append(a[0])  #每段文字的評分list
#             print(score)
            reviews_score = round(statistics.mean(score)*100+40,2)  #該商品所有評論分數的平均數*100，取小數2位
            print(reviews_score)
        except FileNotFoundError as fnf :
            print(fnf)
            pass
        except ValueError as valerr :
            print(valerr)
            pass
        print('---'+ i +'---')
        
        total_score.append(reviews_score)
        items.append(i)
    data = {'Item':items,'Score':total_score}
    new_df = pd.DataFrame(columns=['Item','Score'],data=data)
    
    print(new_df)
    
#     save_path='./'+j+'_score.csv'
#     new_df.to_csv(save_path,index=False)
# Out:
# 58.16
# ---FLUID_MILK_WHITE_ONLY---
# 58.55
# ---YOGURT_NOT_MULTI_PACKS---
# 39.72
# ---SOFT_DRINKS_CAN---
# [Errno 2] No such file or directory: './amazon_reviews/SOFT_DRINK_INCL.txt'
# ---SOFT_DRINK_INCL---
# 53.94
# ---CANDY_BARS---
# 45.96
# ---SHREDDED_CHEESE---
# 58.4
# ---MAINSTREAM_WHITE_BREAD---
# 75.66
# ---CONDENSED_SOUP---
# 76.73
# ---ECONOMY_ENTREES_DINNERS---
# 39.34
# ---BANANAS---
# 76.43
# ---SOFT_DRINK_POWDER_POUCHES---
# 71.61
# ---POTATO_CHIPS---
# 68.32
# ---PASTA_CANNED---
# 50.06
# ---ICE_CREAM---
# [Errno 2] No such file or directory: './amazon_reviews/RAMEN_NOODLES_RAMEN_CUPS.txt'
# ---RAMEN_NOODLES_RAMEN_CUPS---
# 77.63
# ---BEER---
# 43.26
# ---100%_PURE_JUICE---
# 54.92
# ---PREMIUM_ENTREES---
# 59.5
# ---VEGETABLES_PLAIN---
# 48.09
# ---TUNA---
#                          Item  Score
# 0       FLUID_MILK_WHITE_ONLY  58.16
# 1      YOGURT_NOT_MULTI_PACKS  58.55
# 2             SOFT_DRINKS_CAN  39.72
# 3             SOFT_DRINK_INCL  39.72
# 4                  CANDY_BARS  53.94
# 5             SHREDDED_CHEESE  45.96
# 6      MAINSTREAM_WHITE_BREAD  58.40
# 7              CONDENSED_SOUP  75.66
# 8     ECONOMY_ENTREES_DINNERS  76.73
# 9                     BANANAS  39.34
# 10  SOFT_DRINK_POWDER_POUCHES  76.43
# 11               POTATO_CHIPS  71.61
# 12               PASTA_CANNED  68.32
# 13                  ICE_CREAM  50.06
# 14   RAMEN_NOODLES_RAMEN_CUPS  50.06
# 15                       BEER  77.63
# 16            100%_PURE_JUICE  43.26
# 17            PREMIUM_ENTREES  54.92
# 18           VEGETABLES_PLAIN  59.50
# 19                       TUNA  48.09
# 71.48
# ---FLUID_MILK_WHITE_ONLY---
# 76.5
# ---YOGURT_NOT_MULTI_PACKS---
# 71.15
# ---SOFT_DRINKS_CAN---
# 77.41
# ---SOFT_DRINK_INCL---
# 77.26
# ---CANDY_BARS---
# 71.73
# ---SHREDDED_CHEESE---
# 73.13
# ---MAINSTREAM_WHITE_BREAD---
# 70.36
# ---CONDENSED_SOUP---
# 64.48
# ---ECONOMY_ENTREES_DINNERS---
# 65.54
# ---BANANAS---
# 75.21
# ---SOFT_DRINK_POWDER_POUCHES---
# 75.95
# ---POTATO_CHIPS---
# 72.62
# ---PASTA_CANNED---
# 73.61
# ---ICE_CREAM---
# 73.46
# ---RAMEN_NOODLES_RAMEN_CUPS---
# 87.5
# ---BEER---
# 74.62
# ---100%_PURE_JUICE---
# 60.18
# ---PREMIUM_ENTREES---
# 61.06
# ---VEGETABLES_PLAIN---
# 66.46
# ---TUNA---
#                          Item  Score
# 0       FLUID_MILK_WHITE_ONLY  71.48
# 1      YOGURT_NOT_MULTI_PACKS  76.50
# 2             SOFT_DRINKS_CAN  71.15
# 3             SOFT_DRINK_INCL  77.41
# 4                  CANDY_BARS  77.26
# 5             SHREDDED_CHEESE  71.73
# 6      MAINSTREAM_WHITE_BREAD  73.13
# 7              CONDENSED_SOUP  70.36
# 8     ECONOMY_ENTREES_DINNERS  64.48
# 9                     BANANAS  65.54
# 10  SOFT_DRINK_POWDER_POUCHES  75.21
# 11               POTATO_CHIPS  75.95
# 12               PASTA_CANNED  72.62
# 13                  ICE_CREAM  73.61
# 14   RAMEN_NOODLES_RAMEN_CUPS  73.46
# 15                       BEER  87.50
# 16            100%_PURE_JUICE  74.62
# 17            PREMIUM_ENTREES  60.18
# 18           VEGETABLES_PLAIN  61.06
# 19                       TUNA  66.46
# [Errno 2] No such file or directory: './wegmans_reviews/FLUID_MILK_WHITE_ONLY.txt'
# ---FLUID_MILK_WHITE_ONLY---
# 45.19
# ---YOGURT_NOT_MULTI_PACKS---
# 55.83
# ---SOFT_DRINKS_CAN---
# 66.46
# ---SOFT_DRINK_INCL---
# 79.26
# ---CANDY_BARS---
# 77.67
# ---SHREDDED_CHEESE---
# 66.5
# ---MAINSTREAM_WHITE_BREAD---
# 56.72
# ---CONDENSED_SOUP---
# 63.09
# ---ECONOMY_ENTREES_DINNERS---
# 67.62
# ---BANANAS---
# [Errno 2] No such file or directory: './wegmans_reviews/SOFT_DRINK_POWDER_POUCHES.txt'
# ---SOFT_DRINK_POWDER_POUCHES---
# 72.23
# ---POTATO_CHIPS---
# [Errno 2] No such file or directory: './wegmans_reviews/PASTA_CANNED.txt'
# ---PASTA_CANNED---
# 73.34
# ---ICE_CREAM---
# 79.86
# ---RAMEN_NOODLES_RAMEN_CUPS---
# 67.45
# ---BEER---
# 56.8
# ---100%_PURE_JUICE---
# [Errno 2] No such file or directory: './wegmans_reviews/PREMIUM_ENTREES.txt'
# ---PREMIUM_ENTREES---
# 55.42
# ---VEGETABLES_PLAIN---
# 72.6
# ---TUNA---
#                          Item  Score
# 0       FLUID_MILK_WHITE_ONLY  66.46
# 1      YOGURT_NOT_MULTI_PACKS  45.19
# 2             SOFT_DRINKS_CAN  55.83
# 3             SOFT_DRINK_INCL  66.46
# 4                  CANDY_BARS  79.26
# 5             SHREDDED_CHEESE  77.67
# 6      MAINSTREAM_WHITE_BREAD  66.50
# 7              CONDENSED_SOUP  56.72
# 8     ECONOMY_ENTREES_DINNERS  63.09
# 9                     BANANAS  67.62
# 10  SOFT_DRINK_POWDER_POUCHES  67.62
# 11               POTATO_CHIPS  72.23
# 12               PASTA_CANNED  72.23
# 13                  ICE_CREAM  73.34
# 14   RAMEN_NOODLES_RAMEN_CUPS  79.86
# 15                       BEER  67.45
# 16            100%_PURE_JUICE  56.80
# 17            PREMIUM_ENTREES  56.80
# 18           VEGETABLES_PLAIN  55.42
# 19                       TUNA  72.60
